# %% [markdown]
# # Recommendation System (BOOKS)

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine,correlation

# %%
# Now To Import Dataset
books=pd.read_csv('C:\\Users\LENOVO\\Downloads\\book (1).csv',encoding='Latin1')

# %%
books
# Out:
#       Unnamed: 0  User.ID                                         Book.Title  \
# 0              1   276726                                Classical Mythology
# 1              2   276729                                       Clara Callan
# 2              3   276729                               Decision in Normandy
# 3              4   276736  Flu: The Story of the Great Influenza Pandemic...
# 4              5   276737                             The Mummies of Urumchi
# ...          ...      ...                                                ...
# 9995        9996   162121       American Fried: Adventures of a Happy Eater.
# 9996        9997   162121                              Cannibal In Manhattan
# 9997        9998   162121                    How to Flirt: A Practical Guide
# 9998        9999   162121                                           Twilight
# 9999       10000   162129                       Kids Say the Darndest Things
#
#       Book.Rating
# 0               5
# ...

# %%
books.head()
# Out:
#    Unnamed: 0  User.ID                                         Book.Title  \
# 0           1   276726                                Classical Mythology
# 1           2   276729                                       Clara Callan
# 2           3   276729                               Decision in Normandy
# 3           4   276736  Flu: The Story of the Great Influenza Pandemic...
# 4           5   276737                             The Mummies of Urumchi
#
#    Book.Rating
# 0            5
# 1            3
# 2            6
# 3            8
# 4            6

# %%
books2=books.iloc[:,1:]
books2
# Out:
#       User.ID                                         Book.Title  Book.Rating
# 0      276726                                Classical Mythology            5
# 1      276729                                       Clara Callan            3
# 2      276729                               Decision in Normandy            6
# 3      276736  Flu: The Story of the Great Influenza Pandemic...            8
# 4      276737                             The Mummies of Urumchi            6
# ...       ...                                                ...          ...
# 9995   162121       American Fried: Adventures of a Happy Eater.            7
# 9996   162121                              Cannibal In Manhattan            9
# 9997   162121                    How to Flirt: A Practical Guide            7
# 9998   162121                                           Twilight            8
# 9999   162129                       Kids Say the Darndest Things            6
#
# [10000 rows x 3 columns]

# %%
# Now By Sorting By Users Id we Get
books2.sort_values(['User.ID'])
# Out:
#       User.ID                                         Book.Title  Book.Rating
# 2401        8                                              Wings            5
# 2400        8  The Western way: A practical guide to the West...            5
# 2399        8                            Ancient Celtic Romances            5
# 2402        8                                           Truckers            5
# 2405        8                                  The Art Of Celtia            7
# ...       ...                                                ...          ...
# 2395   278854      La crÃ³nica del PerÃº (CrÃ³nicas de AmÃ©rica)            7
# 2398   278854  Celtic Mythology (Library of the World's Myths...            8
# 2393   278854                         A corrente de Trewis Scott            7
# 2394   278854                                      As valkÃ­rias            7
# 2397   278854     A Treasury of Irish Myth, Legend, and Folklore            6
#
# [10000 rows x 3 columns]

# %%
#Lets Find Number Of Unique users In the Dataset
len(books2['Book.Title'].unique())
# Out:
# 9659

# %%
# Lets Find Number Of Unique Books In The Dataset
len(books2['Book.Title'].unique())
# Out:
# 9659

# %%
# Now to convert Long Data Into Wide Data we will use Pivot table
books3=books2.pivot_table(index='User.ID',columns='Book.Title',values='Book.Rating').reset_index(drop=True)
books3
# Out:
# Book.Title   Jason, Madison &amp   Other Stories;Merril;1985;McClelland &amp  \
# 0                            NaN                                         NaN
# 1                            NaN                                         NaN
# 2                            NaN                                         NaN
# 3                            NaN                                         NaN
# 4                            NaN                                         NaN
# ...                          ...                                         ...
# 2177                         NaN                                         NaN
# 2178                         NaN                                         NaN
# 2179                         NaN                                         NaN
# 2180                         NaN                                         NaN
# 2181                         NaN                                         NaN
#
# ...

# %%
# Now Replacing The Index Values By Unique user Ids
books3.index=books2['User.ID'].unique()
books3
# Out:
# Book.Title   Jason, Madison &amp   Other Stories;Merril;1985;McClelland &amp  \
# 276726                       NaN                                         NaN
# 276729                       NaN                                         NaN
# 276736                       NaN                                         NaN
# 276737                       NaN                                         NaN
# 276744                       NaN                                         NaN
# ...                          ...                                         ...
# 162107                       NaN                                         NaN
# 162109                       NaN                                         NaN
# 162113                       NaN                                         NaN
# 162121                       NaN                                         NaN
# 162129                       NaN                                         NaN
#
# ...

# %%
# Now To Replace The NaNs From Table With Zero: 
books3.fillna(0,inplace=False)
books3
# Out:
# Book.Title   Jason, Madison &amp   Other Stories;Merril;1985;McClelland &amp  \
# 276726                       NaN                                         NaN
# 276729                       NaN                                         NaN
# 276736                       NaN                                         NaN
# 276737                       NaN                                         NaN
# 276744                       NaN                                         NaN
# ...                          ...                                         ...
# 162107                       NaN                                         NaN
# 162109                       NaN                                         NaN
# 162113                       NaN                                         NaN
# 162121                       NaN                                         NaN
# 162129                       NaN                                         NaN
#
# ...

# %%
import matplotlib

# %%
mat[np.isfinite(mat) == True] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 mat[np.isfinite(mat) == True] = 0
#
# NameError: name 'mat' is not defined

# %%
# Now Calculating Cosine Similarity Between Users on array data
user_sim=1-pairwise_distances(books3.values,metric='cosine')
user_sim
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 # Now Calculating Cosine Similarity Between Users on array data
# ----> 2 user_sim=1-pairwise_distances(books3.values,metric='cosine')
#       3 user_sim
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1889, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1886         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    1887     func = partial(distance.cdist, metric=metric, **kwds)
# -> 1889 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1430, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1427 X, Y, dtype = _return_float_dtype(X, Y)
#    1429 if effective_n_jobs(n_jobs) == 1:
# ...

# %%
# Now To store The results in a Dataframe Format we will use:
user_sim2=pd.DataFrame(user_sim)
user_sim2

# %%
# Now to SET The index and column names to user Ids we will use:
user_sim2.index=books2['User.ID'].unique()
user_sim2.columns=books2['User.ID'].unique()
user_sim2

# %%
# Now To Nullifying Diagonal Values
np.fill_diagonal(user_sim,0)
user_sim2

# %%
# Now To Find The Most Similar Users
user_sim2.idxmax(axis=1)

# %% [markdown]
# # Topic: Books Extraction

# %%
# Now How To Extract The Books in which UserID 162109 & 276729 have Watched

books2[(books2['User.ID']==162109) | (books2['User.ID']==276729)]

# %%
# Now How To Extract the books which UserID 276744 & 276736 Have Watched
books2[(books2['User.ID']==276744) | (books2['User.ID']==276736)]

# %%
user_1=books2[(books2['User.ID']==276729)]
user_2=books2[(books2['User.ID']==276726)]

# %%
user_1['Book.Title']

# %%
user_2['Book.Title']

# %%
pd.merge(user_1,user_2,on='Book.Title',how='outer')
